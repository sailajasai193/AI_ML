# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import matplotlib.pyplot as plt
train_data = pd.read_csv("WDBC_Scaled_Train.csv")
X_train = train_data.iloc[:, 1:].values
y_train = train_data.iloc[:, 0].values
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)

architecture_name = "Single Layer (64)"  
hidden_layers = [64]  
if len(hidden_layers) == 1:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], 1),
        nn.Sigmoid()
    )
else:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], hidden_layers[1]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[1], 1),
        nn.Sigmoid()
    )

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

epochs = 100
loss_list = []

for epoch in range(epochs):
    optimizer.zero_grad() 
    output = model(X_train) 
    loss = criterion(output, y_train)  
    loss.backward() 
    optimizer.step()  
    loss_list.append(loss.item()) 

    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

# Plot the loss curve
plt.figure(figsize=(8, 5))
plt.plot(range(epochs), loss_list, label=architecture_name, color='b')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title(f"Loss vs. Epochs ({architecture_name})")

plt.grid()
plt.show()
# Out:
# Epoch 0, Loss: 0.27887406945228577

# %%
hidden_layers = [10]  
if len(hidden_layers) == 1:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], 1),
        nn.Sigmoid()
    )
else:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], hidden_layers[1]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[1], 1),
        nn.Sigmoid()
    )

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

epochs = 100
loss_list = []

for epoch in range(epochs):
    optimizer.zero_grad() 
    output = model(X_train) 
    loss = criterion(output, y_train)  
    loss.backward() 
    optimizer.step()  
    loss_list.append(loss.item()) 

    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

# Plot the loss curve
plt.figure(figsize=(8, 5))
plt.plot(range(epochs), loss_list, label=architecture_name, color='b')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title(f"SINGLE LAYER Loss vs. Epochs ({10})")
plt.grid()
plt.show()
# Out:
# Epoch 0, Loss: 0.3083398938179016

# %%
hidden_layers = [100]  
if len(hidden_layers) == 1:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], 1),
        nn.Sigmoid()
    )
else:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], hidden_layers[1]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[1], 1),
        nn.Sigmoid()
    )

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

epochs = 100
loss_list = []

for epoch in range(epochs):
    optimizer.zero_grad() 
    output = model(X_train) 
    loss = criterion(output, y_train)  
    loss.backward() 
    optimizer.step()  
    loss_list.append(loss.item()) 

    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

# Plot the loss curve
plt.figure(figsize=(8, 5))
plt.plot(range(epochs), loss_list, label=architecture_name, color='b')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title(f" single layer Loss vs. Epochs ({100})")
plt.grid()
plt.show()
# Out:
# Epoch 0, Loss: 0.2512347102165222

# %%
hidden_layers = [512]  
if len(hidden_layers) == 1:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], 1),
        nn.Sigmoid()
    )
else:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], hidden_layers[1]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[1], 1),
        nn.Sigmoid()
    )

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

epochs = 100
loss_list = []

for epoch in range(epochs):
    optimizer.zero_grad() 
    output = model(X_train) 
    loss = criterion(output, y_train)  
    loss.backward() 
    optimizer.step()  
    loss_list.append(loss.item()) 

    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

# Plot the loss curve
plt.figure(figsize=(8, 5))
plt.plot(range(epochs), loss_list, label=architecture_name, color='b')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title(f"SINGLE LAYER Loss vs. Epochs (512)")

plt.grid()
plt.show()
# Out:
# Epoch 0, Loss: 0.25597432255744934

# %%
###########MULTI LAYERS
hidden_layers = [64,16]  
if len(hidden_layers) == 1:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], 1),
        nn.Sigmoid()
    )
else:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], hidden_layers[1]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[1], 1),
        nn.Sigmoid()
    )

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

epochs = 100
loss_list = []

for epoch in range(epochs):
    optimizer.zero_grad() 
    output = model(X_train) 
    loss = criterion(output, y_train)  
    loss.backward() 
    optimizer.step()  
    loss_list.append(loss.item()) 

    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

# Plot the loss curve
plt.figure(figsize=(8, 5))
plt.plot(range(epochs), loss_list, label=architecture_name, color='b')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title(f"MULTI LAYER Loss vs. Epochs (64,16)")

plt.grid()
plt.show()
# Out:
# Epoch 0, Loss: 0.23912526667118073

# %%
hidden_layers = [128,32]  
if len(hidden_layers) == 1:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], 1),
        nn.Sigmoid()
    )
else:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], hidden_layers[1]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[1], 1),
        nn.Sigmoid()
    )

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

epochs = 100
loss_list = []

for epoch in range(epochs):
    optimizer.zero_grad() 
    output = model(X_train) 
    loss = criterion(output, y_train)  
    loss.backward() 
    optimizer.step()  
    loss_list.append(loss.item()) 

    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

# Plot the loss curve
plt.figure(figsize=(8, 5))
plt.plot(range(epochs), loss_list, label=architecture_name, color='b')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title(f"MULTI LAYER Loss vs. Epochs (128,32)")
plt.grid()
plt.show()
# Out:
# Epoch 0, Loss: 0.23544548451900482

# %%
hidden_layers = [256,64]  
if len(hidden_layers) == 1:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], 1),
        nn.Sigmoid()
    )
else:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], hidden_layers[1]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[1], 1),
        nn.Sigmoid()
    )

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

epochs = 100
loss_list = []

for epoch in range(epochs):
    optimizer.zero_grad() 
    output = model(X_train) 
    loss = criterion(output, y_train)  
    loss.backward() 
    optimizer.step()  
    loss_list.append(loss.item()) 

    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

# Plot the loss curve
plt.figure(figsize=(8, 5))
plt.plot(range(epochs), loss_list, label=architecture_name, color='b')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title(f"MULTI LAYER Loss vs. Epochs (256,64)")
plt.grid()
plt.show()
# Out:
# Epoch 0, Loss: 0.24123993515968323

# %%
hidden_layers = [512,128]  
if len(hidden_layers) == 1:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], 1),
        nn.Sigmoid()
    )
else:
    model = nn.Sequential(
        nn.Linear(30, hidden_layers[0]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[0], hidden_layers[1]),
        nn.Sigmoid(),
        nn.Linear(hidden_layers[1], 1),
        nn.Sigmoid()
    )

criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

epochs = 100
loss_list = []

for epoch in range(epochs):
    optimizer.zero_grad() 
    output = model(X_train) 
    loss = criterion(output, y_train)  
    loss.backward() 
    optimizer.step()  
    loss_list.append(loss.item()) 

    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

# Plot the loss curve
plt.figure(figsize=(8, 5))
plt.plot(range(epochs), loss_list, label=architecture_name, color='b')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title(f"MULTI LAYER Loss vs. Epochs (512,128)")
plt.grid()
plt.show()
# Out:
# Epoch 0, Loss: 0.25535088777542114
