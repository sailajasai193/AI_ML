# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from seaborn import load_dataset
df=pd.read_csv('Downloads/pima-indians-diabetes.csv')
df
# Out:
#      pregs  plas  pres  skin  test   BMI   pedi  Age  class
# 0        6   148    72    35     0  33.6  0.627   50      1
# 1        1    85    66    29     0  26.6  0.351   31      0
# 2        8   183    64     0     0  23.3  0.672   32      1
# 3        1    89    66    23    94  28.1  0.167   21      0
# 4        0   137    40    35   168  43.1  2.288   33      1
# ..     ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763     10   101    76    48   180  32.9  0.171   63      0
# 764      2   122    70    27     0  36.8  0.340   27      0
# 765      5   121    72    23   112  26.2  0.245   30      0
# 766      1   126    60     0     0  30.1  0.349   47      1
# 767      1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
#q1
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from seaborn import load_dataset
df=pd.read_csv('Downloads/pima-indians-diabetes.csv')
df.head(10)
# Out:
#    pregs  plas  pres  skin  test   BMI   pedi  Age  class
# 0      6   148    72    35     0  33.6  0.627   50      1
# 1      1    85    66    29     0  26.6  0.351   31      0
# 2      8   183    64     0     0  23.3  0.672   32      1
# 3      1    89    66    23    94  28.1  0.167   21      0
# 4      0   137    40    35   168  43.1  2.288   33      1
# 5      5   116    74     0     0  25.6  0.201   30      0
# 6      3    78    50    32    88  31.0  0.248   26      1
# 7     10   115     0     0     0  35.3  0.134   29      0
# 8      2   197    70    45   543  30.5  0.158   53      1
# 9      8   125    96     0     0   0.0  0.232   54      1

# %%
#q2
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from seaborn import load_dataset
df=pd.read_csv('Downloads/pima-indians-diabetes.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pregs   768 non-null    int64
#  1   plas    768 non-null    int64
#  2   pres    768 non-null    int64
#  3   skin    768 non-null    int64
#  4   test    768 non-null    int64
#  5   BMI     768 non-null    float64
#  6   pedi    768 non-null    float64
#  7   Age     768 non-null    int64
#  8   class   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#q3
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from seaborn import load_dataset
df=pd.read_csv('Downloads/pima-indians-diabetes.csv')
df.describe()
# Out:
#             pregs        plas        pres        skin        test         BMI  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         Age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
#q4
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from seaborn import load_dataset
df=pd.read_csv('Downloads/pima-indians-diabetes.csv')
mean=df.mean()
print(f"mean of data is {mean}")
median=df.median()
print(f"median of data is {median}")
mode=df.mode()
print(f"mode of data is {mode}")
minimum=df.min()
print(f"minimum of data is {minimum}")
maximum=df.max()
print(f"maximum of data is {maximum}")
st=df.std()
print(f"standard eviation  of data is {st}")
q1=df.quantile(0.25)
print(f"quartile1 of data is {q1}")
q2=df.quantile(0.5)
print(f"quartile2 of data is {q2}")
q3=df.quantile(0.75)
print(f"quartile3 of data is {q3}")
# Out:
# mean of data is pregs      3.845052
# plas     120.894531
# pres      69.105469
# skin      20.536458
# test      79.799479
# BMI       31.992578
# pedi       0.471876
# Age       33.240885
# class      0.348958
# dtype: float64
# median of data is pregs      3.0000
# plas     117.0000
# pres      72.0000
# skin      23.0000
# test      30.5000
# BMI       32.0000
# pedi       0.3725
# Age       29.0000
# class      0.0000
# dtype: float64
# mode of data is    pregs  plas  pres  skin  test   BMI   pedi   Age  class
# 0    1.0    99  70.0   0.0   0.0  32.0  0.254  22.0    0.0
# 1    NaN   100   NaN   NaN   NaN   NaN  0.258   NaN    NaN
# minimum of data is pregs     0.000
# plas      0.000
# pres      0.000
# skin      0.000
# test      0.000
# BMI       0.000
# pedi      0.078
# Age      21.000
# class     0.000
# dtype: float64
# maximum of data is pregs     17.00
# plas     199.00
# pres     122.00
# skin      99.00
# test     846.00
# BMI       67.10
# pedi       2.42
# ...

# %%
#Question 5
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from seaborn import load_dataset
df=pd.read_csv('Downloads/pima-indians-diabetes.csv')
df.plot(kind='scatter',x='skin',y='Age',color='red')
df.plot(kind='scatter',x='skin',y='BMI',color='red')
df.plot(kind='scatter',x='skin',y='pregs',color='red')
df.plot(kind='scatter',x='skin',y='plas',color='red')
df.plot(kind='scatter',x='Age',y='BMI',color='red')
df.plot(kind='scatter',x='Age',y='pregs',color='red')
df.plot(kind='scatter',x='Age',y='plas',color='red')
df.plot(kind='scatter',x='BMI',y='pregs',color='red')
df.plot(kind='scatter',x='BMI',y='plas',color='red')
df.plot(kind='scatter',x='pregs',y='plas',color='red')
# Out:
# <Axes: xlabel='pregs', ylabel='plas'>

# %%
import seaborn as sns
from seaborn import load_dataset
datas = pd.read_csv('Downloads/pima-indians-diabetes.csv')
sns.histplot(x=datas['skin'],bins=10, kde=True, data=datas)
plt.xlabel('Skin')
plt.ylabel('Frequency')
plt.show()
sns.histplot(x=datas['Age'],bins=10, kde=True, data=datas)
plt.show()
sns.histplot(x=datas['BMI'],bins=10, kde=True, data=datas)
plt.show()
sns.histplot(x=datas['pregs'],bins=10, kde=True, data=datas)
plt.show()
sns.histplot(x=datas['plas'],bins=10, kde=True, data=datas)
plt.show()

# %%
df_titanic = pd.read_csv('Downloads/pima-indians-diabetes.csv')
df_titanic_fare= df_titanic.groupby('class')[['skin','Age','BMI','pregs','plas']].sum()
df_titanic_fare.plot(kind='bar', color='teal')
# Out:
# <Axes: xlabel='class'>

# %%
sns.boxplot(x='skin',data=datas)
plt.title('Box Plot of Skin')
plt.show()
sns.boxplot(x='Age',data=datas)
plt.title('Box Plot of Age')
plt.show()
sns.boxplot(x='BMI',data=datas)
plt.title('Box Plot of BMI')
plt.show()
sns.boxplot(x='pregs',data=datas)
plt.title('Box Plot of pregs')
plt.show()
sns.boxplot(x='plas',data=datas)
plt.title('Box Plot of plas')
plt.show()
